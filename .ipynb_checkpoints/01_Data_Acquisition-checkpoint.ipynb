# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd

pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', 80)

df = pd.read_csv("data/fake_review_dataset.csv")

df.head()
# Out:
#                               review_id       user_name                                                                      review_text  rating  helpful_votes app_version          review_date developer_reply developer_reply_date         app_name
# 0  016bbd04-7f9c-4c2b-8f82-8d7cab4f424f     Sean Harris  always happy with their service and goods,just changed to amazon.ie so hope ...       5              0  32.4.0.100  2026-03-11 18:25:22             NaN                  NaN  Amazon Shopping
# 1  7a6f39b1-5534-4eed-8100-1cdbedc5ea1e  Finn Fiechtner  pros and cons. 3 star review dead center. cons: the ai marketing techniques ...       3              0         NaN  2026-03-11 18:15:01             NaN                  NaN  Amazon Shopping
# 2  967d3ed1-6855-493d-8816-d7434a22180c   Bassam Yousre  the worst delivery service ever always not on time and they promise you with...       1              0  32.5.0.100  2026-03-11 18:08:16             NaN                  NaN  Amazon Shopping
# 3  9767efd5-66d8-4dc8-a86f-2c2a26bd0ee4         SO SUPO                                                                            happy       4              0  32.5.0.100  2026-03-11 17:57:29             NaN                  NaN  Amazon Shopping
# 4  26cf286d-c77c-4c64-ba92-dbb119a510fe       Steve Day  Says my phone is not compatible with tap to pay. So I can't pay. Can't pay, ...       1              0  32.5.0.100  2026-03-11 16:45:46             NaN                  NaN  Amazon Shopping

# %%
print("Dataset Shape:", df.shape)
# Out:
# Dataset Shape: (70000, 10)

# %%
# Show all column names in the dataset
print("Columns in dataset:")
print(df.columns)
# Out:
# Columns in dataset:
# Index(['review_id', 'user_name', 'review_text', 'rating', 'helpful_votes', 'app_version', 'review_date', 'developer_reply', 'developer_reply_date', 'app_name'], dtype='object')
